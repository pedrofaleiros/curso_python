# %%
import matplotlib.pyplot as plt

# %%
# nao recomendado quando tem valores:
# nulos, negativos, ou muito valores

# %%
jogador = ['Gabigol', 'Arrascaeta']
gols = [26, 14]

fig , ax = plt.subplots()
ax.pie(gols, labels=jogador, autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x290174f7c10>,
# ...
#  [Text(-0.49938947630209496, 0.9801072140121811, 'Gabigol'),
#   Text(0.49938938453783227, -0.9801072607683943, 'Arrascaeta')],
#  [Text(-0.2723942598011427, 0.5346039349157351, '65.00%'),
#   Text(0.27239420974790846, -0.5346039604191241, '35.00%')])
