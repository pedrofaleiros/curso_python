# %%
import matplotlib.pyplot as plt

# %%
x = [1, 1.25, 1.5, 2, 2.25]
y = [3, 3.5, 4, 4.5, 5]

plt.scatter(x, y, color='green') #marker='' , muda simbolo
plt.plot(x, y)

# %%
xp = [1, 1, 1.5, 2, 2]
yp = [3, 3.5, 4, 4.5, 5]
xp1 = [3, 3, 3.5, 4, 2]
yp1 = [2, 2.5, 3, 3.5, 2]
x = [1, 2, 3, 4]
y = [2, 3, 4, 5]
plt.plot(x, y)
plt.scatter(xp, yp)
plt.scatter(xp1, yp1)
