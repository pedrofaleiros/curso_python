# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4])

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.title('Grafico Teste')
plt.ylabel('eixo Y')
plt.xlabel('eixo X')
#primeiro é o eixo x
#segundo eixo y
# Out:
# Text(0.5, 0, 'eixo X')
