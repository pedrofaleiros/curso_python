# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 3, 5, 7, 9], [2, 4, 6, 8, 10], label='linha 1', color='red', linestyle='dashed')
plt.plot([2, 4, 6, 8, 10], [1, 3, 5, 7, 9], label='linha 2', linestyle='dotted')
plt.legend()
